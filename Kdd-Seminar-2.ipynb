# %%
from recordlinkage.datasets import load_febrl3 #Task -1.a

# %%
df = load_febrl3() #Task -1.a

# %%
df.head(5) #Task -1.a
# Out:
#                given_name   surname street_number        address_1  \
# rec_id
# rec-1496-org     mitchell     green             7    wallaby place
# rec-552-dup-3      harley  mccarthy           177    pridhamstreet
# rec-988-dup-1    madeline     mason            54  hoseason street
# rec-1716-dup-1   isabelle       NaN            23    gundulu place
# rec-1213-org       taylor  hathaway             7   yuranigh court
#
#                              address_2     suburb postcode state  \
# rec_id
# rec-1496-org                    delmar  cleveland     2119    sa
# rec-552-dup-3                   milton    marsden     3165   nsw
# rec-988-dup-1   lakefront retrmnt vlge  granville     4881   nsw
# rec-1716-dup-1               currin ga   utakarra     2193    wa
# rec-1213-org            brentwood vlge        NaN     4220   nsw
#
#                date_of_birth soc_sec_id
# rec_id
# rec-1496-org        19560409    1804974
# rec-552-dup-3       19080419    6089216
# ...

# %%
df.shape #Task -1.a
# Out:
# (5000, 10)

# %%
import recordlinkage #Task -1.b

# %%
index1 = recordlinkage.Index() #Task -1.b.1

# %%
index1.full() # #Task -1.b.1
# Out:
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.

# %%
pair_1 = index1.index(df) #Task -1.b.1

# %%
len(pair_1) #Task -1.b.2
# Out:
# 12497500

# %%
index2 = recordlinkage.Index()
index2.block(['given_name']) #Task -1.b.3
pair_2 = index2.index(df)

# %%
len(pair_2) #Task -1.b.3
# Out:
# 39775

# %%
pair_2[0] #Task -1.b.4
# Out:
# ('rec-1671-dup-0', 'rec-442-dup-0')

# %%
df[df.index == 'rec-1740-dup-2'] #Task -1.b.4
# Out:
#                given_name surname street_number        address_1  \
# rec_id
# rec-1740-dup-2   mitchell   boyld            10  crozier circuit
#
#                      address_2     suburb postcode state date_of_birth  \
# rec_id
# rec-1740-dup-2  kinross street  spearwood     2640    sa      19860317
#
#                soc_sec_id
# rec_id
# rec-1740-dup-2    5796583

# %%
df[df.index == 'rec-1496-org'] #Task -1.b.4
# Out:
#              given_name surname street_number      address_1 address_2  \
# rec_id
# rec-1496-org   mitchell   green             7  wallaby place    delmar
#
#                  suburb postcode state date_of_birth soc_sec_id
# rec_id
# rec-1496-org  cleveland     2119    sa      19560409    1804974

# %%
df[df['given_name'] == 'mitchell'] #Task -1.b.4
# Out:
#                given_name     surname street_number              address_1  \
# rec_id
# rec-1496-org     mitchell       green             7          wallaby place
# rec-1740-dup-2   mitchell       boyld            10        crozier circuit
# rec-1132-org     mitchell      waller            66         brewster place
# rec-257-org      mitchell      corbin           450         magenta square
# rec-1125-org     mitchell  palachicky            10          adinda street
# rec-1596-dup-0   mitchell     bellamy           NaN           arthurdircle
# rec-437-org      mitchell    quilliam           370        bromell circuit
# rec-1725-dup-4   mitchell   richmaond            38           fidge steret
# rec-1740-dup-1   mitchell         NaN            10       crozier ctircuit
# rec-1596-org     mitchell     bellamy             4          arthur circle
# rec-1664-org     mitchell       david            86          filshie close
# ...

# %%
index3 = recordlinkage.Index()
index3.sortedneighbourhood(['given_name'], window = 3) #Task -1.b.5
pair_3 = index3.index(df)

# %%
len(pair_3) #Task -1.b.5
# Out:
# 54804

# %%
index4 = recordlinkage.Index()
index4.sortedneighbourhood(['given_name'], window = 1) #Task -1.b.5
pair_4 = index4.index(df)

# %%
len(pair_4) #Task -1.b.5
# Out:
# 39775

# %%
df[df.index == 'rec-1740-dup-2'] #Task -1.b.6
# Out:
#                given_name surname street_number        address_1  \
# rec_id
# rec-1740-dup-2   mitchell   boyld            10  crozier circuit
#
#                      address_2     suburb postcode state date_of_birth  \
# rec_id
# rec-1740-dup-2  kinross street  spearwood     2640    sa      19860317
#
#                soc_sec_id
# rec_id
# rec-1740-dup-2    5796583

# %%
df[df.index == 'rec-1496-org'] #Task -1.b.6
# Out:
#              given_name surname street_number      address_1 address_2  \
# rec_id
# rec-1496-org   mitchell   green             7  wallaby place    delmar
#
#                  suburb postcode state date_of_birth soc_sec_id
# rec_id
# rec-1496-org  cleveland     2119    sa      19560409    1804974

# %%
col1 = recordlinkage.Compare()
col1.exact('given_name', 'given_name', label='given_name')  #Task -1.c.1

# %%
fea1 = col1.compute(pair_3, df)
fea1.sum(axis=1).value_counts() #Task -1.c.2
# Out:
# 1    39775
# 0    15029
# Name: count, dtype: int64

# %%
fea1[fea1.sum(axis=1)==1].head(3)
# Out:
#                                given_name
# rec_id_1       rec_id_2
# rec-1671-dup-0 rec-442-dup-0            1
# rec-1723-org   rec-1723-dup-1           1
# rec-799-org    rec-182-org              1

# %%
df[df.index =='rec-1740-dup-2']
# Out:
#                given_name surname street_number        address_1  \
# rec_id
# rec-1740-dup-2   mitchell   boyld            10  crozier circuit
#
#                      address_2     suburb postcode state date_of_birth  \
# rec_id
# rec-1740-dup-2  kinross street  spearwood     2640    sa      19860317
#
#                soc_sec_id
# rec_id
# rec-1740-dup-2    5796583

# %%
df[df.index =='rec-1496-org']
# Out:
#              given_name surname street_number      address_1 address_2  \
# rec_id
# rec-1496-org   mitchell   green             7  wallaby place    delmar
#
#                  suburb postcode state date_of_birth soc_sec_id
# rec_id
# rec-1496-org  cleveland     2119    sa      19560409    1804974

# %%
fea1[fea1.sum(axis=1)==0].head(3)
# Out:
#                                given_name
# rec_id_1       rec_id_2
# rec-382-dup-0  rec-1716-dup-1           0
# rec-1217-dup-0 rec-552-dup-3            0
# rec-408-org    rec-408-dup-2            0

# %%
df[df.index =='rec-1664-org']
# Out:
#              given_name surname street_number      address_1      address_2  \
# rec_id
# rec-1664-org   mitchell   david            86  filshie close  bellbird ctge
#
#                         suburb postcode state date_of_birth soc_sec_id
# rec_id
# rec-1664-org  avondale heights     6107   qld      19990325    5476289

# %%
df[df.index =='rec-1725-dup-0']
# Out:
#                given_name   surname street_number     address_1  \
# rec_id
# rec-1725-dup-0   mitchrll  richmond            38  fidge street
#
#                       address_2       suburb postcode state date_of_birth  \
# rec_id
# rec-1725-dup-0  wentworth house  blair athol     6148   nsw      19110605
#
#                soc_sec_id
# rec_id
# rec-1725-dup-0    4392610

# %%
col2 = recordlinkage.Compare()
col2.exact('given_name', 'given_name', label='given_name')
col2.string('surname', 'surname', threshold= 0.85, label = 'surname')

fea2 = col2.compute(pair_3, df)
fea2.sum(axis=1).value_counts() #Task -1.c.3
# Out:
# 1.0    37462
# 0.0    14645
# 2.0     2697
# Name: count, dtype: int64

# %%
fea2[fea2.sum(axis=1)==2].head(10) #Task -1.c.3
# Out:
#                                given_name  surname
# rec_id_1       rec_id_2
# rec-1723-org   rec-1723-dup-1           1      1.0
# rec-729-dup-0  rec-729-org              1      1.0
# rec-885-dup-1  rec-885-org              1      1.0
# rec-1667-dup-0 rec-1667-dup-1           1      1.0
# rec-421-org    rec-421-dup-3            1      1.0
# rec-152-dup-0  rec-152-org              1      1.0
# rec-517-dup-1  rec-517-dup-4            1      1.0
# rec-960-org    rec-960-dup-1            1      1.0
# rec-292-org    rec-292-dup-0            1      1.0
# rec-108-dup-1  rec-108-org              1      1.0

# %%
df[df.index =='rec-1596-org'] #Task -1.c.3
# Out:
#              given_name  surname street_number      address_1 address_2  \
# rec_id
# rec-1596-org   mitchell  bellamy             4  arthur circle    bolaro
#
#                  suburb postcode state date_of_birth soc_sec_id
# rec_id
# rec-1596-org  coonalpyn     6210   vic      19710203    1090549

# %%
df[df.index =='rec-1596-dup-0'] #Task -1.c.3
# Out:
#                given_name  surname street_number     address_1 address_2  \
# rec_id
# rec-1596-dup-0   mitchell  bellamy           NaN  arthurdircle    bolsro
#
#                    suburb postcode state date_of_birth soc_sec_id
# rec_id
# rec-1596-dup-0  coonalypn     6210   vic      19710203    1090549

# %%
import pandas as pd

# %%
df = pd.read_csv('./Data/Data/DuplicateData.csv', sep=';')

# %%
df
# Out:
#    Customer ID               Name           Address
# 0         3346        Just Vorfan  Harbourstreet 12
# 1         3346      Justin Vorfan    Harbourstr. 12
# 2         4219       Claire Grube   Main Street 345
# 3         5252         Lilo Pause        Cowroad 42
# 4         5268         Lisa Pause        Cowroad 42
# 5         6542  Bernhard Scheuert    Lindenallee 17
# 6         7245            Ann Joy       Domplace 2a
# 7         7246         Anne Scheu       Domplace 28
# 8         8211        Carmen Bert        Am Ring 25
# 9         8234         Chris Baum     Waldstreet 44

# %%
df.shape
# Out:
# (10, 3)

# %%
ind = recordlinkage.Index()
ind.sortedneighbourhood(['Customer ID'], window = 3) #Task -1.b.5
pair_00 = ind.index(df)

# %%
pair_00[0]
# Out:
# (1, 0)

# %%
coln = recordlinkage.Compare()
